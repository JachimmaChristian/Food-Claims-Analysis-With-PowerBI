# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1
# For every column in the data:
#
# a. State whether the values match the description given in the table above.
#
# b. State the number of missing values in the column.
#
# c. Describe what you did to make values match the description if they did not
# match

# %% [markdown]
# **Solution:**
#
# **claim_id:** There were 2000 unique values that match the description given. There are no missing values. No changes were made to this column.
#
# **time_to_close:** The values of this column ranged from 76 to 518 and match the description given. There were no missing values. No changes were made to this column.
#
# **claim_amount:** The values of this column were all rounded to 2 decimal places and ranged from 1637.94 to 76106.80. There were no missing values,however the 'R$' Brazilian currency logo was removed, and the data type converted from text to decimal number to make the values match the description given.
#
# **amount_paid:** The values of this column were all rounded to 2 decimal places ranged from 1516.72 to 52498.75. There were 36 (NA) missing values. The missing values were replaced with the median value of the remaining data, which was 20105.70 and the data type converted from text to decimal number to match the description given.
#
# **location:** This column had four unique categories,'RECIFE', 'FORTALEZA', 'SAO LUIS', 'NATAL', that match the description given. There were no missing values. No changes were made to this column.
#
# **individual_on_claim:** The values of this column range from 1 to 15, and match those in the description. There were no missing values hence no changes were made to this column.
#
# **linked_cases:** The values in this column were either TRUE or FALSE that match the description given. There were 26 (NA) missing values. All missing values were replaced with FALSE.
#
# **Cause:** This column had three unique categories,'vegetable','meat' and 'unknown' that match those in the description. But had two additional categories that didn't match the description, 'Meat' and 'VEGETABLES', both were renamed to match the description.

# %% [markdown]
# ## Task 2
#
# Create a visualization that shows the number of claims in each location. Use the
# visualization to:
#
# a. State which category of the variable location has the most observations
#
# b. Explain whether the observations are balanced across categories of the
# variable location

# %% [markdown]
# Solution:
#
# ![Number of claims by location](column_chart.png)
#
# There are four categories of the variable location as shown in the graph above.
#
# The location with the most observations is Recife, with 885 observations.
#
# The observations are not balanced across categories of the variable location, Recife has 885 observations, Sao Luís has 517 observations, Fortaleza has 311 observations, and Natal has 287 observations.
#
# This means that there are more observations for Recife than for the other three categories. The legal team should focus on Recife as they are the location with the most observations.

# %% [markdown]
# ## Task 3
#
# Describe the distribution of time to close for all claims. Your answer must include a
# visualization that shows the distribution.

# %% [markdown]
# ![Distribution of time to close for all claims](histogram_time_to_close.png)
#
# The graph above shows that the distribution of time to close for all claims is right-skewed. This means that there are a few claims that took a very long time to close, while the majority of claims took a shorter amount of time to close.
#
# The histogram shows that the most common time to close a claim is 76-86 days. There are also a significant number of claims that took 87-96 days to close. However, there are a few claims that took much longer to close, with the longest claims taking over 300 days to close.
#
# The outliers in the distribution of time to close indicates rare instances of claims taking over 300 days to close. These claims may have been more complex or involved more people. However, it is also possible that there were delays in the claims process that could have been avoided. The team should consider investigating further into these.

# %% [markdown]
# ## Task 4
#
# Describe the relationship between time to close and location. Your answer must
# include a visualization to demonstrate the relationship.

# %% [markdown]
# ![Relationship between time to close and location](area_chart.png)
#
# We want to comibine two pieces of information to see how location impacts the time_to_close. From the graph above, the relationship between time_to_close and location is a positive relationship because as the claims in each location increases the time_to_close increases.
#
# The area chart shows that the claims that took the longest time to close are in Recife, with 44.25% of the grand total, this is followed by Sao Luís at 25.85%, Fortaleza, with 15.55%, and Natal, with 14.35%.
#
# Based on these, I'll recommend that the legal team should increase the number of staff in Recife as this would help to reduce the backlog of claims and speed up the process of closing claims and also provide more training to staff in Recife on how to handle complex claims this would help to ensure that claims are processed more efficiently and effectively.
#
# Most importantly I will recommend for further research to be done, to analyze the data for other factors that may be affecting the time to close claims such as claim amount and individuals on claim.impact of population of a location on time_to_close.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
